# %%
#Create an algorithm to rank weekend places to travel given any city name

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Top Indian Places to Visit.csv")
df.head()
# Out:
#    Unnamed: 0      Zone  State   City                  Name          Type
# 0           0  Northern  Delhi  Delhi            India Gate  War Memorial  \
# 1           1  Northern  Delhi  Delhi        Humayun's Tomb          Tomb
# 2           2  Northern  Delhi  Delhi     Akshardham Temple        Temple
# 3           3  Northern  Delhi  Delhi  Waste to Wonder Park    Theme Park
# 4           4  Northern  Delhi  Delhi         Jantar Mantar   Observatory
#
#   Establishment Year  time needed to visit in hrs  Google review rating
# 0               1921                          0.5                   4.6  \
# 1               1572                          2.0                   4.5
# 2               2005                          5.0                   4.6
# 3               2019                          2.0                   4.1
# 4               1724                          2.0                   4.2
#
#    Entrance Fee in INR Airport with 50km Radius Weekly Off   Significance
# 0                    0                      Yes        NaN     Historical  \
# 1                   30                      Yes        NaN     Historical
# 2                   60                      Yes        NaN      Religious
# 3                   50                      Yes     Monday  Environmental
# 4                   15                      Yes        NaN     Scientific
#
#   DSLR Allowed  Number of google review in lakhs Best Time to visit
# 0          Yes                              2.60            Evening
# 1          Yes                              0.40          Afternoon
# 2           No                              0.40          Afternoon
# 3          Yes                              0.27            Evening
# 4          Yes                              0.31            Morning

# %%
df.sample(10)
# Out:
#      Unnamed: 0      Zone          State           City
# 6             6  Northern          Delhi          Delhi  \
# 71           71   Western        Gujarat        Somnath
# 34           34  Southern      Telangana      Hyderabad
# 207         207  Northern         Ladakh           Dras
# 107         107  Southern         Kerala         Kannur
# 268         268   Eastern         Sikkim         Namchi
# 89           89  Northern      Rajasthan         Jaipur
# 134         134   Western    Maharashtra       Matheran
# 117         117  Southern      Karnataka     Shivamogga
# 315         315   Central  Uttar Pradesh  Greater Noida
#
#                             Name               Type Establishment Year
# 6                   Lotus Temple             Temple               1986  \
# 71                Somnath Temple             Temple               1951
# 34            Hussain Sagar Lake               Lake               1563
# 207            Dras War Memorial       War Memorial            Unknown
# 107              St. Angelo Fort               Fort               1505
# 268                    Char Dham  Religious Complex                211
# 89                    Amber Fort               Fort               1592
# 134                   Echo Point          Viewpoint               1828
# 117                    Jog Falls          Waterfall               1900
# 315  Buddh International Circuit         Race Track               2011
#
#      time needed to visit in hrs  Google review rating  Entrance Fee in INR
# 6                            1.0                   4.5                    0  \
# 71                           2.0                   4.8                    0
# 34                           1.0                   4.3                    0
# 207                          1.0                   4.8                    0
# 107                          1.0                   4.4                   20
# 268                          2.0                   4.7                   50
# 89                           2.0                   4.6                  100
# 134                          1.5                   4.4                    0
# 117                          1.5                   4.6                   30
# 315                          2.0                   4.6                 1500
#
#     Airport with 50km Radius Weekly Off Significance DSLR Allowed
# 6                        Yes     Monday    Religious          Yes  \
# 71                        No        NaN    Religious           No
# 34                       Yes        NaN       Scenic          Yes
# 207                       No        NaN   Historical          Yes
# 107                      Yes        NaN   Historical          Yes
# 268                      Yes        NaN    Religious           No
# 89                       Yes        NaN   Historical          Yes
# 134                      Yes        NaN       Nature          Yes
# 117                       No        NaN       Nature          Yes
# 315                      Yes     Sunday       Sports          Yes
#
#      Number of google review in lakhs Best Time to visit
# 6                               0.590            Evening
# 71                              0.390            Morning
# 34                              0.500            Evening
# 207                             0.012                All
# 107                             0.110                All
# 268                             0.120                All
# 89                              1.500                All
# 134                             0.020            Morning
# 117                             0.230            Morning
# 315                             7.400                All

# %%
df=df.drop(columns=['Unnamed: 0', 'Establishment Year','Weekly Off','Zone','State','Significance','Type'])
df.sample(10)
# Out:
#            City                       Name  time needed to visit in hrs
# 282    Agartala           Ujjayanta Palace                          1.5  \
# 290  Port Blair              Cellular Jail                          1.5
# 59          Goa                 Baga Beach                          2.0
# 157     Kinnaur              Sangla Valley                          2.0
# 81    Jaisalmer             Jaisalmer Fort                          2.5
# 40    Hyderabad      Nehru Zoological Park                          3.0
# 13        Delhi  National Zoological Park                           3.0
# 132    Tarkarli             Tarkarli Beach                          2.0
# 45      Kolkata   Dakshineswar Kali Temple                          1.0
# 297      Ranchi              Pahari Mandir                          1.0
#
#      Google review rating  Entrance Fee in INR Airport with 50km Radius
# 282                   4.5                   10                      Yes  \
# 290                   4.7                   30                      Yes
# 59                    4.5                    0                      Yes
# 157                   4.5                    0                       No
# 81                    4.4                   50                       No
# 40                    4.2                   50                      Yes
# 13                    4.1                   80                      Yes
# 132                   4.6                    0                       No
# 45                    4.7                    0                      Yes
# 297                   4.6                    0                      Yes
#
#     DSLR Allowed  Number of google review in lakhs Best Time to visit
# 282          Yes                             0.035                All
# 290          Yes                             0.120          Afternoon
# 59           Yes                             0.350            Evening
# 157          Yes                             0.010            Morning
# 81           Yes                             0.560                All
# 40           Yes                             0.860            Morning
# 13           Yes                             0.410                All
# 132          Yes                             0.065            Evening
# 45           Yes                             0.820            Morning
# 297          Yes                             0.130                All

# %%
#df.info()

# %%
df['Best Time to visit'].value_counts()
# Out:
# Best Time to visit
# All          164
# Morning       88
# Afternoon     44
# Evening       26
# All            1
# Anytime        1
# Night          1
# Name: count, dtype: int64

# %%
df['DSLR Allowed'] = df['DSLR Allowed'].replace({'Yes'or'yes': 1, 'No'or'no': 0})
df['Best Time to visit'] = df['Best Time to visit'].replace({'All':3,'All ':3,'Anytime':3,'Morning':2,'Afternoon':2,'Evening':1,'Night':0})
df['Airport with 50km Radius'] = df['Airport with 50km Radius'].replace({'Yes'or'yes': 1, 'No'or'no': 0})

# %%
df['Best Time to visit'].value_counts()
# Out:
# Best Time to visit
# 3    166
# 2    132
# 1     26
# 0      1
# Name: count, dtype: int64

# %%
df = df.assign(Rating = df['Google review rating'] * df['Number of google review in lakhs'])

# %%
df=df.drop(columns=['Google review rating','Number of google review in lakhs'])
df.sample(10)
# Out:
#               City                     Name  time needed to visit in hrs
# 93        Amritsar         Jallianwala Bagh                          1.0  \
# 226         Konark               Sun Temple                          1.5
# 216       Siliguri  Jaldapara National Park                          3.0
# 230      Sambalpur              Hirakud Dam                          1.0
# 308  Greater Noida    The Grand Venice Mall                          2.0
# 297         Ranchi            Pahari Mandir                          1.0
# 118      Mangalore           Panambur Beach                          1.5
# 14           Delhi              Qutub Minar                          1.0
# 17          Mumbai         Gateway of India                          1.0
# 309      Bengaluru  Wonderla Amusement Park                          4.0
#
#      Entrance Fee in INR  Airport with 50km Radius  DSLR Allowed
# 93                     0                         1             1  \
# 226                   40                         1             1
# 216                  250                         1             1
# 230                    0                         0             1
# 308                    0                         1             1
# 297                    0                         1             1
# 118                    0                         1             1
# 14                    35                         1             1
# 17                     0                         1             1
# 309                  890                         1             1
#
#      Best Time to visit  Rating
# 93                    2   1.440
# 226                   3   3.901
# 216                   3   0.154
# 230                   3   0.045
# 308                   3   1.890
# 297                   3   0.598
# 118                   3   0.450
# 14                    2   6.165
# 17                    3  16.560
# 309                   3   4.275

# %%
df.columns
# Out:
# Index(['City', 'Name', 'time needed to visit in hrs', 'Entrance Fee in INR',
#        'Airport with 50km Radius', 'DSLR Allowed', 'Best Time to visit',
#        'Rating'],
#       dtype='object')

# %%
# Filter the DataFrame for the city name 'Delhi'
delhi_df = df[df['City'] == 'Delhi']

# Print all the names present in the filtered DataFrame
print(delhi_df['Name'].unique())
# Out:
# ['India Gate' "Humayun's Tomb" 'Akshardham Temple' 'Waste to Wonder Park'
#  'Jantar Mantar' 'Chandni Chowk' 'Lotus Temple' 'Red Fort'
#  'Agrasen ki Baoli' 'Sunder Nursery' 'Garden of Five Senses'
#  'Lodhi Garden' 'National Gallery of Modern Art'
#  'National Zoological Park ' 'Qutub Minar' 'National Science Centre']

# %%
df.columns
# Out:
# Index(['City', 'Name', 'time needed to visit in hrs', 'Entrance Fee in INR',
#        'Airport with 50km Radius', 'DSLR Allowed', 'Best Time to visit',
#        'Rating'],
#       dtype='object')

# %%
# Define Weighted Scoring Function
def calculate_score(row, weights):
    score = 0
    for column_name, weight in weights.items():
        score += row[column_name] * weight
        #score += row[time needed to visit in hrs] *-1
    return score

# Define User Preferences
weights = {
    'time needed to visit in hrs': -1,  # Minimize time needed
    'Entrance Fee in INR': -1,  # Minimize entrance fee
    'Airport with 50km Radius': 1,  # Prefer airport within 50km
    'DSLR Allowed': 1,  # Prefer DSLR allowed
    'Best Time to visit': 1,  # Prefer best time to visit
    'Rating': 1  # Prefer higher rating
}

# Filter DataFrame for Given City
city_name = 'Delhi'
city_df = df[df['City'] == city_name]

# Apply Weighted Scoring Function to Filtered DataFrame
city_df['Score'] = city_df.apply(lambda row: calculate_score(row, weights), axis=1)
sorted_df = city_df.sort_values(by='Score', ascending=False)
#top_5_places = sorted_df.head(5)['Name'].tolist()
print(sorted_df.head(5)['Name'].tolist())
# Out:
# ['India Gate', 'Lodhi Garden', 'Agrasen ki Baoli', 'Lotus Temple', 'Sunder Nursery']
# C:\Users\biswa\AppData\Local\Temp\ipykernel_5604\2346794206.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city_df['Score'] = city_df.apply(lambda row: calculate_score(row, user_preferences), axis=1)
